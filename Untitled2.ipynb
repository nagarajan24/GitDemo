# %%
from pandas_datareader import data, wb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25932/1895358925.py in <module>
# ----> 1 from pandas_datareader import data, wb
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
from pandas_datareader import data, web
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25932/2846438375.py in <module>
# ----> 1 from pandas_datareader import data, web
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
from pandas_DataReader import data, wb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25932/1553977343.py in <module>
# ----> 1 from pandas_DataReader import data, wb
#
# ModuleNotFoundError: No module named 'pandas_DataReader'

# %%
from pandas_DataReader import data, web
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25932/253212218.py in <module>
# ----> 1 from pandas_DataReader import data, web
#
# ModuleNotFoundError: No module named 'pandas_DataReader'
