# %%
import pandas.io.data as web
df = web.Datareader('AAPL','google','2020/1/1','2021/1/1')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17564/2514408393.py in <module>
# ----> 1 import pandas.io.data as web
#       2 df = web.Datareader('AAPL','google','2020/1/1','2021/1/1')
#       3 df.head()
#
# ModuleNotFoundError: No module named 'pandas.io.data'

# %%
import pandas.io.data as web
df = web.Datareader('AAPL','google','2020/1/1','2021/1/1')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17564/2514408393.py in <module>
# ----> 1 import pandas.io.data as web
#       2 df = web.Datareader('AAPL','google','2020/1/1','2021/1/1')
#       3 df.head()
#
# ModuleNotFoundError: No module named 'pandas.io.data'

# %%
from pandas_datareader import data, wb

# %%
df = data.Datareader('AAPL','google','2020/1/1','2021/1/1')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17564/3691599990.py in <module>
# ----> 1 df = data.Datareader('AAPL','google','2020/1/1','2021/1/1')
#
# AttributeError: module 'pandas_datareader.data' has no attribute 'Datareader'

# %%
from pandas_datareader import data, wb
df = data.Datareader('AAPL','google','2020/1/1','2021/1/1')
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17564/3908707398.py in <module>
#       1 from pandas_datareader import data, wb
# ----> 2 df = data.Datareader('AAPL','google','2020/1/1','2021/1/1')
#       3 df.head()
#
# AttributeError: module 'pandas_datareader.data' has no attribute 'Datareader'

# %%
from pandas_datareader import data, wb
df = data.DataReader('AAPL','google','2020/1/1','2021/1/1')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17564/3668743623.py in <module>
#       1 from pandas_datareader import data, wb
# ----> 2 df = data.DataReader('AAPL','google','2020/1/1','2021/1/1')
#       3 df.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     365     if data_source not in expected_source:
#     366         msg = "data_source=%r is not implemented" % data_source
# --> 367         raise NotImplementedError(msg)
# ...
